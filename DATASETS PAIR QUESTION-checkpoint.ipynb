# %%
import pandas as pd

# %%
df = pd.read_csv('/content/duplicate_questions_pairs.xls')

# %%
df
# Out:
#             id    qid1    qid2  \
# 0            0       1       2
# 1            1       3       4
# 2            2       5       6
# 3            3       7       8
# 4            4       9      10
# ...        ...     ...     ...
# 404285  404285  433578  379845
# 404286  404286   18840  155606
# 404287  404287  537928  537929
# 404288  404288  537930  537931
# 404289  404289  537932  537933
#
#                                                 question1  \
# 0       What is the step by step guide to invest in sh...
# 1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2       How can I increase the speed of my internet co...
# 3       Why am I mentally very lonely? How can I solve...
# 4       Which one dissolve in water quikly sugar, salt...
# ...                                                   ...
# 404285  How many keywords are there in the Racket prog...
# 404286          Do you believe there is life after death?
# ...

# %%
df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       0
# question2       0
# is_duplicate    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['is_duplicate'].value_counts()
# Out:
# is_duplicate
# 0    255024
# 1    149263
# Name: count, dtype: int64

# %%
df1 = df.iloc[:10000]

# %%
df1.shape
# Out:
# (10000, 6)

# %%
df1['is_duplicate'].value_counts()
# Out:
# is_duplicate
# 0    6289
# 1    3711
# Name: count, dtype: int64

# %%
print("Total questions:", len(df1))
print("Duplicate questions:", df1['is_duplicate'].sum())
print("Non-duplicate questions:", len(df1) - df1['is_duplicate'].sum())
# Out:
# Total questions: 10000
# Duplicate questions: 3711
# Non-duplicate questions: 6289

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dup_count = df1['is_duplicate'].value_counts()

plt.figure(figsize=(6,4))
sns.barplot(x=dup_count.index, y=dup_count.values)
plt.xticks([0,1], ['Not Duplicate', 'Duplicate'])
plt.title('Distribution of Duplicate vs Non-Duplicate Questions')
plt.ylabel('Number of Question Pairs')
plt.xlabel('Question Type')
plt.tight_layout()
plt.show()

# %%
all_qids = df1['qid1'].tolist() + df1['qid2'].tolist()

unique_qids = set(all_qids)
print("Number of unique questions:", len(unique_qids))

from collections import Counter
qid_counts = Counter(all_qids)

repeated_questions = [qid for qid, count in qid_counts.items() if count > 1]
print("Number of questions getting repeated:", len(repeated_questions))
# Out:
# Number of unique questions: 19413
# Number of questions getting repeated: 536

# %%
non_repeated = len(unique_qids)
repeated = len(repeated_questions)

# 🔸 Pie chart labels & data
labels = ['Repeated Questions', 'Unique (Not Repeated)']
sizes = [repeated, non_repeated]
colors = ['lightcoral', 'skyblue']

plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Repeated vs Unique Questions (by QID)')
plt.axis('equal')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Length of Each Question

# %%
df1['q1_len'] = df1['question1'].apply(lambda x: len(str(x)))
df1['q2_len'] = df1['question2'].apply(lambda x: len(str(x)))

# %%
print(df1[['q1_len', 'q2_len']].describe())
# Out:
#              q1_len        q2_len
# count  10000.000000  10000.000000
# mean      59.523700     59.933800
# std       30.121161     34.982401
# min        1.000000     11.000000
# 25%       39.000000     39.000000
# 50%       52.000000     51.000000
# 75%       71.000000     71.000000
# max      370.000000   1169.000000

# %%
df1
# Out:
#         id   qid1   qid2                                          question1  \
# 0        0      1      2  What is the step by step guide to invest in sh...
# 1        1      3      4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2        2      5      6  How can I increase the speed of my internet co...
# 3        3      7      8  Why am I mentally very lonely? How can I solve...
# 4        4      9     10  Which one dissolve in water quikly sugar, salt...
# ...    ...    ...    ...                                                ...
# 9995  9995  19404  19405  How would you order these four cities (Bangalo...
# 9996  9996  19406  19407                            Stphen william hawking?
# 9997  9997  19408  19409  Mathematical Puzzles: What is () + () + () = 3...
# 9998  9998  19410  19411                         Is IMS noida good for BCA?
# 9999  9999  19412  19413  What are the most respected and informative te...
#
# ...

# %% [markdown]
# # Average Words per Question

# %%
df1['q1_words'] = df1['question1'].apply(lambda x: len(str(x).split()))
df1['q2_words'] = df1['question2'].apply(lambda x: len(str(x).split()))

print(df1[['q1_words', 'q2_words']].describe())
# Out:
#            q1_words      q2_words
# count  10000.000000  10000.000000
# mean      10.961700     11.165600
# std        5.476736      6.552257
# min        1.000000      3.000000
# 25%        7.000000      7.000000
# 50%       10.000000      9.000000
# 75%       13.000000     13.000000
# max       66.000000    228.000000

# %%
df1['q2_words'].max()
# Out:
# 228

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.histplot(df1['q1_words'], bins=30, color='skyblue', label='Question1 Words', kde=True)
sns.histplot(df1['q2_words'], bins=30, color='lightcoral', label='Question2 Words', kde=True)
plt.legend()
plt.title('Distribution of Word Count per Question')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # balanced dataset

# %%
a = df1[df1['is_duplicate']==0]
b = df1[df1['is_duplicate']==1]

# %%
a.shape,b.shape
# Out:
# ((6289, 10), (3711, 10))

# %%
a = a.sample(b.shape[0])

# %%
a.shape,b.shape
# Out:
# ((3711, 10), (3711, 10))

# %%
df1 = pd.concat([a,b],ignore_index=True)

# %%
value = df1['is_duplicate'].value_counts()

# %%
plt.figure(figsize=(5,5))
plt.pie(value, labels=['Not Duplicate', 'Duplicate'], autopct='%1.1f%%', startangle=90, colors=['skyblue','lightcoral'])
plt.show()

# %%
import nltk
from nltk.corpus import stopwords
from string  import punctuation
from nltk.tokenize import  word_tokenize
nltk.download('stopwords')
nltk.download('punkt_tab')
pun = list(punctuation)
stop = stopwords.words('english')
from nltk.stem import SnowballStemmer
sw = SnowballStemmer('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
def transform(text):
    text = text.lower()
    token = nltk.word_tokenize(text)
    y = []
    for i in token:
        if i.isalnum():
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        if  i not in pun and i not in stop:
            y.append(i)
    text = y[:]
    y.clear()

    for  i in text:
        stem = sw.stem(i)
        y.append(stem)

    return ' '.join(y)

# %%
df1.head(1)
# Out:
#      id  qid1  qid2                     question1                  question2  \
# 0  4156  8222  8223  How should I forgive myself?  How do you truly forgive?
#
#    is_duplicate  q1_len  q2_len  q1_words  q2_words
# 0             0      28      25         5         5

# %%
df1['question1'] = df1['question1'].apply(transform)

# %%
df1['question2'] = df1['question2'].apply(transform)

# %%
df1
# Out:
#         id   qid1   qid2                                         question1  \
# 0     4156   8222   8223                                            forgiv
# 1     2425   4819   4820                               web script cms made
# 2     9366  18201  18202                           cathol pray peopl saint
# 3     3596   7125   7126         tip make job interview process vca antech
# 4     7040  13770  13771  nazi germani abl technolog surpass alli mani way
# ...    ...    ...    ...                                               ...
# 7417  9987  19391  18678                                come famili friend
# 7418  9988  19392  19393                              first masturb experi
# 7419  9990  19396  10565   500 1000 rs note ban goi new note 500 2000 issu
# 7420  9992  19399   1214                               world war go happen
# 7421  9998  19410  19411                                 im noida good bca
#
# ...

# %%
x = df1[['question1','question2']]
y = df1['is_duplicate']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((5195, 2), (2227, 2))

# %%
y_train
# Out:
# 3660    0
# 4554    1
# 272     0
# 2042    0
# 3757    1
#        ..
# 5191    1
# 5226    1
# 5390    1
# 860     0
# 7270    1
# Name: is_duplicate, Length: 5195, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()

# %%
x_train_bow = cv.fit_transform(x_train['question1']+''+x_train['question2']).toarray()
x_test_bow = cv.transform(x_test['question1']+''+x_test['question2']).toarray()

# %%
from sklearn.ensemble  import  RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train_bow,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score , confusion_matrix

# %%
y_pred = rf.predict(x_test_bow)

# %%
accuracy_score(y_pred,y_test)*100
# Out:
# 63.89762011674899

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[679, 365],
#        [439, 744]])

# %%
a = input('enter ques1')
b = input('enter ques2')
c = cv.transform([a+''+b]).toarray()
d = rf.predict(c)
print(d)
# Out:
# enter ques1What is the step by step guide to invest in
# enter ques2What is the step by step guide to invest in
# [0]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer()

# %%
x_train_tfidf = tfidf.fit_transform(x_train['question1']+''+x_train['question2']).toarray()
x_test_tfidf = tfidf.transform(x_test['question1']+''+x_test['question2']).toarray()

# %%
from sklearn.naive_bayes  import GaussianNB

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train_tfidf,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test_tfidf)

# %%
accuracy_score(y_pred,y_test)*100
# Out:
# 64.93039964077234
